# %% [markdown]
# # Walking
# The purpose of this notebook is to to refine a policy that has learned to move by trotting around into a policy that wlaks properly.
#
# As usual the directory will contain all the necessary for the execution of this notebook.

# %%
import time
import numpy as np
from stable_baselines3 import PPO

import sys
import os

# Start from the current working directory (where notebook is)
cwd = os.getcwd()

# Go two levels up (to the "grandparent")
grandparent_dir = os.path.abspath(os.path.join(cwd, "..", ".."))

# Add to sys.path if not already there
if grandparent_dir not in sys.path:
    sys.path.insert(0, grandparent_dir)

from SpotmicroEnv import SpotmicroEnv
from reward_function import reward_function, RewardState
# Out:
# pybullet build time: Apr  4 2025 18:56:19

# %% [markdown]
# # Training

# %%
from stable_baselines3.common.callbacks import CheckpointCallback
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.logger import configure

# ========= CONFIG ==========
TOTAL_STEPS = 16_000_000
run = "walk"
base="trot"

log_dir = f"./logs/{run}"

def clipped_linear_schedule(initial_value, min_value=1e-5):
    def schedule(progress_remaining):
        return max(progress_remaining * initial_value, min_value)
    return schedule

checkpoint_callback = CheckpointCallback(
    save_freq=TOTAL_STEPS // 16,
    save_path=f"{run}_checkpoints",
    name_prefix=f"ppo_{run}"
)

# ========= ENV ==========
env = SpotmicroEnv(
    use_gui=False,
    reward_fn=reward_function, 
    reward_state=RewardState(),
    src_save_file=f"{base}.pkl",
    dest_save_file=f"{run}.pkl"
)
check_env(env, warn=True)

# ========= MODEL ==========
model = PPO.load(f"ppo_{base}")
model.set_env(env)
model.tensorboard_log = log_dir

# Custom logger: ONLY csv + tensorboard (no stdout table)
new_logger = configure(log_dir, ["csv", "tensorboard"])
model.set_logger(new_logger)

# %%
# %load_ext tensorboard
# %tensorboard --logdir ./logs
# Out:
#       <iframe id="tensorboard-frame-ece6d836daa9a8d3" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ece6d836daa9a8d3");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
model.learn(
    total_timesteps=TOTAL_STEPS,
    reset_num_timesteps=False,
    callback=checkpoint_callback
)
model.save(f"ppo_{run}")
env.close()

# %% [markdown]
# # Evaluation

# %%
policy = "walk"

env = SpotmicroEnv(
    use_gui=True, 
    reward_fn=reward_function,
    reward_state=RewardState(),
    src_save_file=f"{policy}.pkl"
    )
obs, _ = env.reset()

# === Load model ===
model = PPO.load(f"ppo_{policy}")
#model = PPO.load(f"{policy}_checkpoints/ppo_{policy}_14001216_steps")

# === Run rollout ===
for _ in range(3001):
    action, _ = model.predict(obs, deterministic=True)
    obs, reward, terminated, truncated, info = env.step(action)

    if terminated or truncated:
        print("Terminated")
        env.plot_reward_components()
        obs, _ = env.reset()
    time.sleep(1/60)

env.close()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[7], line 18
#      16 for _ in range(3001):
#      17     action, _ = model.predict(obs, deterministic=True)
# ---> 18     obs, reward, terminated, truncated, info = env.step(action)
#      20     if terminated or truncated:
#      21         print("Terminated")
#
# File ~/aea_spot_micro/policy_training/SpotmicroEnv.py:223, in SpotmicroEnv.step(self, action)
#     221     reward, reward_info = self._calculate_reward(action)
#     222 else:                                                                         # reuse last action
# --> 223     observation = self._step_simulation(self._agent.previous_action)
#     224     reward, reward_info = self._calculate_reward(self._agent.previous_action)
#     226 terminated, term_penalty = self._is_target_state() # checks wether the agent has fallen or not
#
# File ~/aea_spot_micro/policy_training/SpotmicroEnv.py:277, in SpotmicroEnv._step_simulation(self, action)
#     271 """
#     272 Private method that calls the API to execute the given action in PyBullet.
#     273 It should sinchronize the state of the agent in the simulation with the state recorded here!
#     274 Accepts an action and returns an observation
#     275 """
#     276 # Execute the action in pybullet
# --> 277 self._agent.apply_action(action)
#     279 self._episode_step_counter += 1 #updates the step counter (used to check against timeouts)
#     281 if self._terrain.config.mode == "tilting":
#
# File ~/aea_spot_micro/policy_training/Agent.py:178, in Agent.apply_action(self, action)
#     175 self._action = action
#     177 for i, joint in enumerate(self._motor_joints):
# --> 178     pybullet.setJointMotorControl2(
#     179         bodyUniqueId = self._robot_id,
#     180         jointIndex = joint.id,
#     181         controlMode = pybullet.POSITION_CONTROL,
#     182         targetPosition = joint.from_action_to_position(action[i]),
#     183         force = joint.max_torque
#     184     )
#     186 return
#
# error: Not connected to physics server.
